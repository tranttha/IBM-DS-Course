# %% [markdown]
# # COURSE 6: Database and SQL for DS
# # DB & SQL for DS

# %% [markdown]
# ## Prerequisite:

# %% [markdown]
# TODO: Preform API calls using the sodapy library to interact with the Socrata API (*API docs at: https://dev.socrata.com/foundry/data.sfgov.org/yitu-d5am* )
#
# TODO: create and store Film Locations in San Francisco data in a db wtih sqlite3 from datasette
#
# 1. Install datasette
# 2. Import bs4, requests

# %%
# !pip install datasette 
# !pip install datasette requests
# !pip install sodapy

# %%
import bs4 as bs 
import datasette 
import requests
import sqlite3

# %%
import pandas as pd
from sodapy import Socrata

# %%
def fetch_data(endpoint,limit=1000):
    all_response = []
    offset = 0
    client = Socrata("data.sfgov.org", None)
    while True:
        # driver code using sodapy
        try:
            response = client.get(endpoint, limit=limit, offset=offset)
        
        except Exception as e:
            print(f'Failed to retrieve data: Reason: {e}')
            break
        
        if not response:
            print(f'No data left to retrieve after offset: {offset}')
            break
        
        # Append the data to all_response
        all_response.extend(response)
        offset += limit
        
    results_df = pd.DataFrame.from_records(all_response)

    
    return results_df

endpoint = "yitu-d5am"

# Fetch the data
df = fetch_data(endpoint)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# No data left to retrieve after offset: 3000

# %%
# Create a SQLite database
conn = sqlite3.connect('FilmLocations.db')
cursor = conn.cursor()

# %%
# Create a table
cursor.execute('''
    CREATE TABLE IF NOT EXISTS FilmLocations (
        title TEXT,
        release_year TEXT,
        locations TEXT,
        fun_facts TEXT,
        production_company TEXT,
        distributor TEXT,
        director TEXT,
        writer TEXT,
        actor_1 TEXT,
        actor_2 TEXT,
        actor_3 TEXT
    )
''')

# Insert the data into the table
df.to_sql('FilmLocations', conn, if_exists='replace', index=False)

# Commit and close the connection
conn.commit()
conn.close()
print("Loaded and stored in FilmLocations.db")
# Out:
# Loaded and stored in FilmLocations.db

# %% [markdown]
# ## THE LABS

# %% [markdown]
# **Note** : before running sql queries, open a connection to the db -> query(ies) -> assign query result(s) to pd df(s) -> close connection

# %% [markdown]
# ### Select statement:

# %% [markdown]
# Suppose we want to retrieve details of all the films from the FilmLocations table. The details of each film record should contain all the columns. The query statement for this is:
#
# **SELECT * FROM FileLocations LIMIT 10**

# %%
# Connect to the SQLite database
conn = sqlite3.connect('FilmLocations.db')

# Define the SQL query
query1 = "SELECT * FROM FilmLocations"  # Example query to select the first 10 rows
# Execute the query and load the result into a DataFrame
df1 = pd.read_sql_query(query1, conn)

# Display the DataFrame
df1
# Out:
#                        title release_year  \
# 0       Experiment in Terror         1962
# 1       Experiment in Terror         1962
# 2            Chan is Missing         1982
# 3           A View to a Kill         1985
# 4           The Californians         2005
# ...                      ...          ...
# 2079                 Vertigo         1958
# 2080            Love & Taxes         2014
# 2081  Chance- Season 1 ep109         2016
# 2082         Women is Losers         2020
# 2083                Godzilla         2014
#
#                                               locations  \
# 0           The Sea Captain's Chest (Fisherman's Wharf)
# 1                                100 St. Germain Avenue
# 2     Li Po (916 Grant Avenue at Washington, Chinatown)
# 3      Taylor and Jefferson Streets (Fisherman's Wharf)
# 4                                                  None
# ...                                                 ...
# 2079                                 900 Lombard Street
# 2080           The Marsh Theatre (1062 Valencia Street)
# 2081                            Terry A. Francois Blvd.
# 2082                                    1132 Florida St
# 2083                                 Potrero &San Bruno
#
#                    production_company                   distributor  \
# 0       Columbia Pictures Corporation             Columbia Pictures
# 1       Columbia Pictures Corporation             Columbia Pictures
# 2                    New Yorker Films              New Yorker Films
# 3                 Metro-Goldwyn Mayer  MGM/UA Entertainment Company
# 4                 Parker Film Company             Fabrication Films
# ...                               ...                           ...
# 2079  Alfred J. Hitchcock Productions            Paramount Pictures
# 2080                Bad Company Films                          None
# 2081                  TVM Productions                          HULU
# 2082        Look at the Moon Pictures                          None
# 2083        Nautilus Productions, LLC         Warner Bros. Pictures
#
#                        director                                writer  \
# 0                 Blake Edwards                           The Gordons
# 1                 Blake Edwards                           The Gordons
# 2                    Wayne Wang                            Wayne Wang
# 3                     John Glen                       Richard Maibaum
# 4               Jonathan Parker  Jonathan Parker & Catherine DiNapoli
# ...                         ...                                   ...
# 2079           Alfred Hitchcock                           Alec Coppel
# 2080            Jacob Kornbluth                       Jacob Kornbluth
# 2081  Sara Gran and Pete Begler                            Dan Attias
# 2082         Lissette Feliciano                    Lissette Feliciano
# 2083             Gareth Edwards                        Max Borenstein
#
#                    actor_1             actor_2             actor_3  \
# 0               Glenn Ford          Lee Remick     Stefanie Powers
# 1               Glenn Ford          Lee Remick     Stefanie Powers
# 2                 Wood Moy        Marc Hayashi         Lauren Chew
# 3              Roger Moore  Christopher Walken       Tanya Roberts
# 4                Noah Wyle                None                None
# ...                    ...                 ...                 ...
# 2079         James Stewart           Kim Novak  Barbara Bel Geddes
# 2080       Jacob Kornbluth                None                None
# 2081           Hugh Laurie        Gretchen Mol        Ethan Suplee
# 2082          Lorenza Izzo            Simu Liu           Liza Weil
# 2083  Aaron Taylor-Johnson     Elizabeth Olsen      Bryan Cranston
#
#      :@computed_region_6qbp_sg9q :@computed_region_ajp5_b2md  \
# 0                             99                          23
# 1                             47                          38
# 2                            104                           6
# 3                             99                          23
# 4                             21                          36
# ...                          ...                         ...
# 2079                         107                          32
# 2080                          52                          20
# 2081                          34                           4
# 2082                          53                          20
# 2083                          54                          26
#
#      :@computed_region_26cr_cadq  \
# 0                              3
# 1                              8
# 2                              3
# 3                              3
# 4                             10
# ...                          ...
# 2079                           6
# 2080                           5
# 2081                          10
# 2082                           2
# 2083                           9
#
#                                               fun_facts
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 2079  Lombard Street is not actually the most crooke...
# 2080                                               None
# 2081                                               None
# 2082                                               None
# 2083                                               None
#
# [2084 rows x 14 columns]

# %% [markdown]
# **SELECT Title, Director, Writer FROM FilmLocations;**

# %%
query2 = "SELECT title, director, writer FROM FilmLocations"
df2 = pd.read_sql_query(query2, conn)

df2.head()
# Out:
#                   title         director                                writer
# 0  Experiment in Terror    Blake Edwards                           The Gordons
# 1  Experiment in Terror    Blake Edwards                           The Gordons
# 2       Chan is Missing       Wayne Wang                            Wayne Wang
# 3      A View to a Kill        John Glen                       Richard Maibaum
# 4      The Californians  Jonathan Parker  Jonathan Parker & Catherine DiNapoli

# %%
query3 = "SELECT title, release_year, locations FROM FilmLocations WHERE release_year>=2001;"
df3 = pd.read_sql_query(query3,conn)

df3.head()
# Out:
#               title release_year                   locations
# 0  The Californians         2005                        None
# 1            Babies         2010                        None
# 2               I's         2011               1 Post Street
# 3      When We Rise         2017                  Bay Bridge
# 4      Nash Bridges         2021  California Street at Davis

# %% [markdown]
# ### PRACTICE **SELECT**

# %% [markdown]
# 1. Retrieve the fun facts and filming locations of all films.

# %%
prac1_query = "SELECT fun_facts, locations FROM FilmLocations"
df_ans1 = pd.read_sql_query(prac1_query,conn)

df_ans1
# Out:
#                                               fun_facts  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 2079  Lombard Street is not actually the most crooke...
# 2080                                               None
# 2081                                               None
# 2082                                               None
# 2083                                               None
#
#                                               locations
# 0           The Sea Captain's Chest (Fisherman's Wharf)
# 1                                100 St. Germain Avenue
# 2     Li Po (916 Grant Avenue at Washington, Chinatown)
# 3      Taylor and Jefferson Streets (Fisherman's Wharf)
# 4                                                  None
# ...                                                 ...
# 2079                                 900 Lombard Street
# 2080           The Marsh Theatre (1062 Valencia Street)
# 2081                            Terry A. Francois Blvd.
# 2082                                    1132 Florida St
# 2083                                 Potrero &San Bruno
#
# [2084 rows x 2 columns]

# %% [markdown]
# 2. Retrieve the names of all films released in the 20th century and before (release years before 2000 including 2000), along with filming locations and release years.

# %%
prac2_query = "SELECT title, locations, release_year FROM FilmLocations WHERE release_year >= 2000;"
df_ans2 = pd.read_sql_query(prac2_query, conn)

df_ans2
# Out:
#                        title                                 locations  \
# 0           The Californians                                      None
# 1                     Babies                                      None
# 2                        I's                             1 Post Street
# 3               When We Rise                                Bay Bridge
# 4               Nash Bridges                California Street at Davis
# ...                      ...                                       ...
# 1362                Alcatraz             Broadway from Mason to Taylor
# 1363            Love & Taxes  The Marsh Theatre (1062 Valencia Street)
# 1364  Chance- Season 1 ep109                   Terry A. Francois Blvd.
# 1365         Women is Losers                           1132 Florida St
# 1366                Godzilla                        Potrero &San Bruno
#
#      release_year
# 0            2005
# 1            2010
# 2            2011
# 3            2017
# 4            2021
# ...           ...
# 1362         2012
# 1363         2014
# 1364         2016
# 1365         2020
# 1366         2014
#
# [1367 rows x 3 columns]

# %% [markdown]
# 3. Retrieve the names, production company names, filming locations, and release years of the films not written by James Cameron.

# %%
prac3_query = "SELECT title, production_company, locations, release_year FROM FilmLocations WHERE writer != 'James Cameron';" 
df_ans3 = pd.read_sql_query(prac3_query, conn)

df_ans3
# Out:
#                        title               production_company  \
# 0       Experiment in Terror    Columbia Pictures Corporation
# 1       Experiment in Terror    Columbia Pictures Corporation
# 2            Chan is Missing                 New Yorker Films
# 3           A View to a Kill              Metro-Goldwyn Mayer
# 4           The Californians              Parker Film Company
# ...                      ...                              ...
# 2049                 Vertigo  Alfred J. Hitchcock Productions
# 2050            Love & Taxes                Bad Company Films
# 2051  Chance- Season 1 ep109                  TVM Productions
# 2052         Women is Losers        Look at the Moon Pictures
# 2053                Godzilla        Nautilus Productions, LLC
#
#                                               locations release_year
# 0           The Sea Captain's Chest (Fisherman's Wharf)         1962
# 1                                100 St. Germain Avenue         1962
# 2     Li Po (916 Grant Avenue at Washington, Chinatown)         1982
# 3      Taylor and Jefferson Streets (Fisherman's Wharf)         1985
# 4                                                  None         2005
# ...                                                 ...          ...
# 2049                                 900 Lombard Street         1958
# 2050           The Marsh Theatre (1062 Valencia Street)         2014
# 2051                            Terry A. Francois Blvd.         2016
# 2052                                    1132 Florida St         2020
# 2053                                 Potrero &San Bruno         2014
#
# [2054 rows x 4 columns]

# %% [markdown]
# ## COUNT, DISCTINCT, LIMIT

# %% [markdown]
# ### COUNT

# %% [markdown]
# 1. Suppose we want to count the number of records or rows of the "FilmLocations" table. The query for this would be:

# %%
query4 = "SELECT COUNT(*) FROM FilmLocations;"
df4 = pd.read_sql_query(query4, conn)
df4
# Out:
#    COUNT(*)
# 0      2084

# %% [markdown]
# 2. We want to count the number of locations of the films. But we also want to restrict the output result set so that we only retrieve the number of locations of the films written by a certain writer. The query for this can be written as:

# %%
query5 = "SELECT COUNT(locations) FROM FilmLocations WHERE writer == 'James Cameron';"

df5 = pd.read_sql_query(query5, conn)
df5
# Out:
#    COUNT(locations)
# 0                24

# %% [markdown]
# ### DISTINCT

# %% [markdown]
# 1. Assume that we want to retrieve the titles of all films in the table so that duplicates will be discarded in the output result set.

# %%
query6 = "SELECT DISTINCT title FROM FilmLocations;"

df6 = pd.read_sql_query(query6, conn)
df6
# Out:
#                       title
# 0      Experiment in Terror
# 1           Chan is Missing
# 2          A View to a Kill
# 3          The Californians
# 4                    Babies
# ..                      ...
# 331        Another 48 Hours
# 332  Chance - Season 1ep105
# 333                Superman
# 334                 The Fan
# 335       Seven Girlfriends
#
# [336 rows x 1 columns]

# %%
query7 = "SELECT COUNT(DISTINCT release_year) FROM FilmLocations WHERE production_company=='Warner Bros. Pictures';"
df7 = pd.read_sql_query(query7,conn)
df7
# Out:
#    COUNT(DISTINCT release_year)
# 0                            14

# %% [markdown]
# ### LIMIT

# %% [markdown]
# 1. Retrieve only the first 25 rows from the table so that rows other than those are not in the output result set.

# %%
query8 = "SELECT * FROM FilmLocations lIMIT 25;"
df8 = pd.read_sql_query(query8,conn)
df8
# Out:
#                             title release_year  \
# 0            Experiment in Terror         1962
# 1            Experiment in Terror         1962
# 2                 Chan is Missing         1982
# 3                A View to a Kill         1985
# 4                The Californians         2005
# 5                          Babies         2010
# 6                             I's         2011
# 7                    When We Rise         2017
# 8                    Nash Bridges         2021
# 9                      This Is Us         2022
# 10                       The Rock         1996
# 11                   Blue Jasmine         2013
# 12               The Caine Mutiny         1954
# 13    The Diary of a Teenage Girl         2015
# 14                          Venom         2018
# 15  Murder in the First, Season 1         2014
# 16                       GirlBoss         2017
# 17              Sense8 - Season 2         2016
# 18       The Pursuit of Happyness         2006
# 19                Women is Losers         2020
# 20            Birth of the Dragon         2016
# 21                 The OA Part II         2019
# 22         Chance- Season 1 ep107         2016
# 23                 Down Periscope         1996
# 24  Murder in the First, Season 1         2014
#
#                                             locations  \
# 0         The Sea Captain's Chest (Fisherman's Wharf)
# 1                              100 St. Germain Avenue
# 2   Li Po (916 Grant Avenue at Washington, Chinatown)
# 3    Taylor and Jefferson Streets (Fisherman's Wharf)
# 4                                                None
# 5                                                None
# 6                                       1 Post Street
# 7                                          Bay Bridge
# 8                          California Street at Davis
# 9                                   Alamo Square Park
# 10                                         Coit Tower
# 11                               Pacific & Divisadero
# 12                                 Golden Gate Bridge
# 13                                     700 Kansas St.
# 14                    Grant Ave btwn Clay and Jackson
# 15                                    13 Lucky Street
# 16                 The Castro Theater, 429 Castro St.
# 17                    Clay between Stockton and Grant
# 18                           Glen Park Subway Station
# 19                                 Capp St at 25th St
# 20                               Leavenworth at Green
# 21             Waverly Pl btwn Washington and Clay St
# 22                                  1958 Valencia St.
# 23                                               None
# 24           Berry Street between 3rd and 4th Streets
#
#                   production_company  \
# 0      Columbia Pictures Corporation
# 1      Columbia Pictures Corporation
# 2                   New Yorker Films
# 3                Metro-Goldwyn Mayer
# 4                Parker Film Company
# 5                             Canal+
# 6                     Banshee Cinema
# 7                Film 49 Productions
# 8        Village NB Productions, LLC
# 9                    20th Television
# 10                Hollywood Pictures
# 11               Perdido Productions
# 12        Stanley Kramer Productions
# 13              Diary the Movie, LLC
# 14          L.O.Z. Productions, Inc.
# 15   Turner North Center Productions
# 16        Hippolyta Productions, LLC
# 17  Unpronounceable Productions, LLC
# 18     Columbia Pictures Corporation
# 19         Look at the Moon Pictures
# 20       BOTD U.S. Productions, Inc.
# 21                  Lunar Mining LLC
# 22                   TVM Productions
# 23  Twentieth Century Fox Film Corp.
# 24   Turner North Center Productions
#
#                                    distributor  \
# 0                            Columbia Pictures
# 1                            Columbia Pictures
# 2                             New Yorker Films
# 3                 MGM/UA Entertainment Company
# 4                            Fabrication Films
# 5                               Focus Features
# 6                                         None
# 7                Amercian Broadcasting Company
# 8                                   USA Nework
# 9                                          NBC
# 10                        Buena Vista Pictures
# 11                      Sony Pictures Classics
# 12                           Columbia Pictures
# 13                      Sony Pictures Classics
# 14  Columbia Pictures, Sony Pictures Releasing
# 15             Turner Network Television (TNT)
# 16                                     Netflix
# 17                                     Netflix
# 18                           Columbia Pictures
# 19                                        None
# 20                              Kylin Pictures
# 21                                     Netflix
# 22                                        HULU
# 23            Twentieth Century Fox Film Corp.
# 24             Turner Network Television (TNT)
#
#                                              director  \
# 0                                       Blake Edwards
# 1                                       Blake Edwards
# 2                                          Wayne Wang
# 3                                           John Glen
# 4                                     Jonathan Parker
# 5                                       Thomas Balmes
# 6                                       Chris Edgette
# 7                                        Gus Van Sant
# 8                                         Greg Beeman
# 9                                         Mandy Moore
# 10                                        Michael Bay
# 11                                        Woody Allen
# 12                                     Edward Dmytryk
# 13                                    Marielle Heller
# 14                                    Ruben Fleischer
# 15                                     Steven Bochcho
# 16  Jamie Babbit, Amanda Brotchie, Steven K. Tsuch...
# 17                                 Wachowski Siblings
# 18                                      Steven Conrad
# 19                                 Lissette Feliciano
# 20                                       George Nolfi
# 21                                     Zal Batmanglij
# 22                  Alexandra Cunningham and Kem Nunn
# 23                                      David S. Ward
# 24                                     Steven Bochcho
#
#                                                writer              actor_1  \
# 0                                         The Gordons           Glenn Ford
# 1                                         The Gordons           Glenn Ford
# 2                                          Wayne Wang             Wood Moy
# 3                                     Richard Maibaum          Roger Moore
# 4                Jonathan Parker & Catherine DiNapoli            Noah Wyle
# 5                                       Thomas Balmes                Bayar
# 6                                           Kyle Tuck                 None
# 7                                  Dustin Lance Black           Guy Pierce
# 8                            Carlton Cuse, Bill Chais          Don Johnson
# 9   Dan Fogelman, Casey Johnson, David Windsor, Ch...     Milo Ventimiglia
# 10                                     David Weisberg         Sean Connery
# 11                                        Woody Allen       Cate Blanchett
# 12                                    Stanley Roberts      Humphrey Bogart
# 13                                    Marielle Heller  Alexander Skarsgard
# 14                      Jeff Pinkner, Scott Rosenberg            Tom Hardy
# 15                                         Eric Lodal           Taye Diggs
# 16                                         Kay Cannon      Britt Robertson
# 17        J. Michael Straczynski, Wachowiski Siblings        Jamie Clayton
# 18                                   Gabriele Muccino           Will Smith
# 19                                 Lissette Feliciano         Lorenza Izzo
# 20           Christopher Wilkinson, Stephen J. Rivele            Philip Ng
# 21                       Zal Batmanglij, Brit Marling         Brit Marling
# 22                                    Michael Lehmann          Hugh Laurie
# 23                                        Hugh Wilson       Kelsey Grammar
# 24                                         Eric Lodal           Taye Diggs
#
#                actor_2                   actor_3 :@computed_region_6qbp_sg9q  \
# 0           Lee Remick           Stefanie Powers                          99
# 1           Lee Remick           Stefanie Powers                          47
# 2         Marc Hayashi               Lauren Chew                         104
# 3   Christopher Walken             Tanya Roberts                          99
# 4                 None                      None                          21
# 5               Hattie                      None                          21
# 6                 None                      None                          19
# 7   Mary-Louise Parker  Michael Kenneth Williams                        None
# 8         Cheech Marin               Joe Dinicol                         108
# 9          Mandy Moore         Sterling K. Brown                          22
# 10        Nicolas Cage                      None                          18
# 11        Alec Baldwin           Peter Sarsgaard                         102
# 12      Fred MacMurray               Jose Ferrer                        None
# 13        Kristen Wiig        Christopher Meloni                          54
# 14    Michelle Wiliams                 Riz Ahmed                         104
# 15  Kathleen Robertson          Ian Anthony Dale                          53
# 16          Ellie Reed                Amanda Rea                          38
# 17        Daryl Hannah            Naveen Andrews                         104
# 18     Jayden C. Smith                      None                          59
# 19            Simu Liu                 Liza Weil                          53
# 20     Billy Magnussen                    Yu Xia                         107
# 21         Emory Cohen            Patrick Gibson                        None
# 22        Gretchen Mol              Ethan Suplee                        None
# 23        Lauren Holly                      None                          21
# 24  Kathleen Robertson          Ian Anthony Dale                        None
#
#    :@computed_region_ajp5_b2md :@computed_region_26cr_cadq  \
# 0                           23                           3
# 1                           38                           8
# 2                            6                           3
# 3                           23                           3
# 4                           36                          10
# 5                           36                          10
# 6                            8                           3
# 7                         None                        None
# 8                            8                           3
# 9                            9                          11
# 10                          23                           3
# 11                          30                           6
# 12                        None                        None
# 13                          26                           9
# 14                           6                           3
# 15                          20                           2
# 16                           5                           5
# 17                           6                           3
# 18                          10                           5
# 19                          20                           2
# 20                          32                           3
# 21                        None                        None
# 22                        None                        None
# 23                          36                          10
# 24                        None                        None
#
#                                             fun_facts
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10  The Tower was funded by a gift bequeathed by L...
# 11                                               None
# 12  With 23 miles of ladders and 300,000 rivets in...
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None

# %% [markdown]
# 2. Now, we want to retrieve 15 rows from the table starting from row 11.

# %%
query9 = "SELECT * FROM FilmLocations lIMIT 15 OFFSET 10;"
df9 = pd.read_sql_query(query9, conn)
df9
# Out:
#                             title release_year  \
# 0                        The Rock         1996
# 1                    Blue Jasmine         2013
# 2                The Caine Mutiny         1954
# 3     The Diary of a Teenage Girl         2015
# 4                           Venom         2018
# 5   Murder in the First, Season 1         2014
# 6                        GirlBoss         2017
# 7               Sense8 - Season 2         2016
# 8        The Pursuit of Happyness         2006
# 9                 Women is Losers         2020
# 10            Birth of the Dragon         2016
# 11                 The OA Part II         2019
# 12         Chance- Season 1 ep107         2016
# 13                 Down Periscope         1996
# 14  Murder in the First, Season 1         2014
#
#                                    locations  \
# 0                                 Coit Tower
# 1                       Pacific & Divisadero
# 2                         Golden Gate Bridge
# 3                             700 Kansas St.
# 4            Grant Ave btwn Clay and Jackson
# 5                            13 Lucky Street
# 6         The Castro Theater, 429 Castro St.
# 7            Clay between Stockton and Grant
# 8                   Glen Park Subway Station
# 9                         Capp St at 25th St
# 10                      Leavenworth at Green
# 11    Waverly Pl btwn Washington and Clay St
# 12                         1958 Valencia St.
# 13                                      None
# 14  Berry Street between 3rd and 4th Streets
#
#                   production_company  \
# 0                 Hollywood Pictures
# 1                Perdido Productions
# 2         Stanley Kramer Productions
# 3               Diary the Movie, LLC
# 4           L.O.Z. Productions, Inc.
# 5    Turner North Center Productions
# 6         Hippolyta Productions, LLC
# 7   Unpronounceable Productions, LLC
# 8      Columbia Pictures Corporation
# 9          Look at the Moon Pictures
# 10       BOTD U.S. Productions, Inc.
# 11                  Lunar Mining LLC
# 12                   TVM Productions
# 13  Twentieth Century Fox Film Corp.
# 14   Turner North Center Productions
#
#                                    distributor  \
# 0                         Buena Vista Pictures
# 1                       Sony Pictures Classics
# 2                            Columbia Pictures
# 3                       Sony Pictures Classics
# 4   Columbia Pictures, Sony Pictures Releasing
# 5              Turner Network Television (TNT)
# 6                                      Netflix
# 7                                      Netflix
# 8                            Columbia Pictures
# 9                                         None
# 10                              Kylin Pictures
# 11                                     Netflix
# 12                                        HULU
# 13            Twentieth Century Fox Film Corp.
# 14             Turner Network Television (TNT)
#
#                                              director  \
# 0                                         Michael Bay
# 1                                         Woody Allen
# 2                                      Edward Dmytryk
# 3                                     Marielle Heller
# 4                                     Ruben Fleischer
# 5                                      Steven Bochcho
# 6   Jamie Babbit, Amanda Brotchie, Steven K. Tsuch...
# 7                                  Wachowski Siblings
# 8                                       Steven Conrad
# 9                                  Lissette Feliciano
# 10                                       George Nolfi
# 11                                     Zal Batmanglij
# 12                  Alexandra Cunningham and Kem Nunn
# 13                                      David S. Ward
# 14                                     Steven Bochcho
#
#                                          writer              actor_1  \
# 0                                David Weisberg         Sean Connery
# 1                                   Woody Allen       Cate Blanchett
# 2                               Stanley Roberts      Humphrey Bogart
# 3                               Marielle Heller  Alexander Skarsgard
# 4                 Jeff Pinkner, Scott Rosenberg            Tom Hardy
# 5                                    Eric Lodal           Taye Diggs
# 6                                    Kay Cannon      Britt Robertson
# 7   J. Michael Straczynski, Wachowiski Siblings        Jamie Clayton
# 8                              Gabriele Muccino           Will Smith
# 9                            Lissette Feliciano         Lorenza Izzo
# 10     Christopher Wilkinson, Stephen J. Rivele            Philip Ng
# 11                 Zal Batmanglij, Brit Marling         Brit Marling
# 12                              Michael Lehmann          Hugh Laurie
# 13                                  Hugh Wilson       Kelsey Grammar
# 14                                   Eric Lodal           Taye Diggs
#
#                actor_2             actor_3 :@computed_region_6qbp_sg9q  \
# 0         Nicolas Cage                None                          18
# 1         Alec Baldwin     Peter Sarsgaard                         102
# 2       Fred MacMurray         Jose Ferrer                        None
# 3         Kristen Wiig  Christopher Meloni                          54
# 4     Michelle Wiliams           Riz Ahmed                         104
# 5   Kathleen Robertson    Ian Anthony Dale                          53
# 6           Ellie Reed          Amanda Rea                          38
# 7         Daryl Hannah      Naveen Andrews                         104
# 8      Jayden C. Smith                None                          59
# 9             Simu Liu           Liza Weil                          53
# 10     Billy Magnussen              Yu Xia                         107
# 11         Emory Cohen      Patrick Gibson                        None
# 12        Gretchen Mol        Ethan Suplee                        None
# 13        Lauren Holly                None                          21
# 14  Kathleen Robertson    Ian Anthony Dale                        None
#
#    :@computed_region_ajp5_b2md :@computed_region_26cr_cadq  \
# 0                           23                           3
# 1                           30                           6
# 2                         None                        None
# 3                           26                           9
# 4                            6                           3
# 5                           20                           2
# 6                            5                           5
# 7                            6                           3
# 8                           10                           5
# 9                           20                           2
# 10                          32                           3
# 11                        None                        None
# 12                        None                        None
# 13                          36                          10
# 14                        None                        None
#
#                                             fun_facts
# 0   The Tower was funded by a gift bequeathed by L...
# 1                                                None
# 2   With 23 miles of ladders and 300,000 rivets in...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None

# %% [markdown]
# ### PRACTICE **COUNT**

# %% [markdown]
# 1. Retrieve the number of locations of the films which are directed by Woody Allen.

# %%
prac4_query = "SELECT COUNT(locations) FROM FilmLocations WHERE director == 'Woody Allen';"
df_ans4 = pd.read_sql_query(prac4_query,conn)
df_ans4
# Out:
#    COUNT(locations)
# 0                31

# %% [markdown]
# 2. Retrieve the number of films shot at Russian Hill.

# %%
prac5_query = "SELECT COUNT(*) FROM FilmLocations WHERE locations == 'Russian Hill';"
df_ans5 = pd.read_sql_query(prac5_query,conn)
df_ans5
# Out:
#    COUNT(*)
# 0         1

# %% [markdown]
# 3. Retrieve the number of rows having a release year older than 1950 from the "FilmLocations" table.

# %%
prac6_query = "SELECT COUNT(*) FROM FilmLocations WHERE release_year <= 1950;"
df_ans6 = pd.read_sql_query(prac6_query,conn)
df_ans6
# Out:
#    COUNT(*)
# 0        47

# %% [markdown]
# ### PRACTICE **DISTINCT**

# %% [markdown]
# 1. Retrieve the names of all unique films released in the 21st century and onwards, along with their release years.

# %%
prac7_query = "SELECT DISTINCT(title), release_year FROM FilmLocations WHERE release_year >= 2001;"
df_ans7 = pd.read_sql_query(prac7_query,conn)
df_ans7
# Out:
#                       title release_year
# 0          The Californians         2005
# 1                    Babies         2010
# 2                       I's         2011
# 3              When We Rise         2017
# 4              Nash Bridges         2021
# ..                      ...          ...
# 141          50 First Dates         2004
# 142      The Sweetest Thing         2002
# 143             Serendipity         2001
# 144          Night of Henna         2005
# 145  Chance - Season 1ep105         2016
#
# [146 rows x 2 columns]

# %% [markdown]
# 2. Retrieve the directors' names and their distinct films shot at City Hall.

# %%
prac7_query = "SELECT DISTINCT(title), director FROM FilmLocations WHERE locations == 'City Hall';"
df_ans7 = pd.read_sql_query(prac7_query,conn)
df_ans7
# Out:
#                              title              director
# 0                    San Francisco         W.S. Van Dyke
# 1           Smile Again, Jenny Lee         Carlo Caldana
# 2              The Wedding Planner         Adam Shankman
# 3                     Magnum Force              Ted Post
# 4                         The Rock           Michael Bay
# 5                     When We Rise          Gus Van Sant
# 6                 A View to a Kill             John Glen
# 7   Invasion of the Body Snatchers        Philip Kaufman
# 8                     The Enforcer           James Fargo
# 9                     Class Action         Michael Apted
# 10                  Boys and Girls         Robert Iscove
# 11                     Knife Fight        Bill Guttentag
# 12  Dawn of the Planet of the Apes           Matt Reeves
# 13                Bicentennial Man        Chris Columbus
# 14                             180              Jayendra
# 15   Tucker: The Man and His Dream  Francis Ford Coppola
# 16                     Jagged Edge      Richard Marquand
# 17                       Bedazzled          Harold Ramis
# 18                       Foul Play         Colin Higgins
# 19                            Milk          Gus Van Sant
# 20                  Final Analysis           Phil Joanou
# 21                 The Right Stuff        Philip Kaufman

# %% [markdown]
# 3. Retrieve the number of distributors who distributed films with the 1st actor, Clint Eastwood.

# %%
prac8_query = "SELECT COUNT (DISTINCT(distributor)) FROM FilmLocations WHERE actor_1 == 'Clint Eastwood';"
df_ans8 = pd.read_sql_query(prac8_query,conn)
df_ans8
# Out:
#    COUNT (DISTINCT(distributor))
# 0                              3

# %% [markdown]
# ### PRACTICE **LIMIT**

# %% [markdown]
# 1. Retrieve the names of the first 50 films.

# %%
prac9_query = "SELECT title FROM FilmLocations LIMIT 50;"
df_ans9 = pd.read_sql_query(prac9_query,conn)
df_ans9
# Out:
#                                   title
# 0                  Experiment in Terror
# 1                  Experiment in Terror
# 2                       Chan is Missing
# 3                      A View to a Kill
# 4                      The Californians
# 5                                Babies
# 6                                   I's
# 7                          When We Rise
# 8                          Nash Bridges
# 9                            This Is Us
# 10                             The Rock
# 11                         Blue Jasmine
# 12                     The Caine Mutiny
# 13          The Diary of a Teenage Girl
# 14                                Venom
# 15        Murder in the First, Season 1
# 16                             GirlBoss
# 17                    Sense8 - Season 2
# 18             The Pursuit of Happyness
# 19                      Women is Losers
# 20                  Birth of the Dragon
# 21                       The OA Part II
# 22               Chance- Season 1 ep107
# 23                       Down Periscope
# 24        Murder in the First, Season 1
# 25                         Pushing Dead
# 26                      The Right Stuff
# 27               Chance- Season 1 ep102
# 28                              Bullitt
# 29                       The Phone/Jexi
# 30                             Quitters
# 31        Murder in the First, Season 2
# 32                       Dr. Dolittle 2
# 33                              Vertigo
# 34        Murder in the First, Season 3
# 35                              Surface
# 36                       The OA Part II
# 37                          I’m A Virgo
# 38  The Last Black Man in San Francisco
# 39                         Nash Bridges
# 40                            Shattered
# 41                       Etruscan Smile
# 42              Looking Season 2 ep 202
# 43                   Always Be My Maybe
# 44                               Sense8
# 45             The Pursuit of Happyness
# 46                         Blue Jasmine
# 47                      Time After Time
# 48                              The Net
# 49        Murder in the First, Season 1

# %% [markdown]
# 2. Retrieve the first 10 film names released in 2015.

# %%
prac10_query = "SELECT title FROM FilmLocations WHERE release_year == 2015 LIMIT 10;"
df_ans10 = pd.read_sql_query(prac10_query,conn)
df_ans10
# Out:
#                            title
# 0    The Diary of a Teenage Girl
# 1                       Quitters
# 2  Murder in the First, Season 2
# 3        Looking Season 2 ep 202
# 4                         Sense8
# 5           Terminator - Genisys
# 6                        Ant-Man
# 7  Murder in the First, Season 2
# 8           Terminator - Genisys
# 9        Looking Season 2 ep 202

# %% [markdown]
# 3. Retrieve the next 3 film names that follow after the first 5 films released in 2015.

# %%
prac11_query = "SELECT title FROM FilmLocations WHERE release_year == 2015 LIMIT 3 OFFSET 5;"
df_ans11 = pd.read_sql_query(prac11_query,conn)
df_ans11
# Out:
#                            title
# 0           Terminator - Genisys
# 1                        Ant-Man
# 2  Murder in the First, Season 2
